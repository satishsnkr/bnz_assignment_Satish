# %%
import requests
import zipfile
import duckdb
import os
import time

# URL of the ZIP file
url1 = "https://www.stats.govt.nz/assets/Uploads/Business-employment-data/Business-employment-data-March-2024-quarter/Download-data/business-employment-data-march-2024-quarter.zip"

local_zip_path1 = './business_employment_data.zip'

extracted_dir = './extracted/'

csv_file_name1 = 'machine-readable-business-employment-data-mar-2024-quarter.csv'

csv_file_path1 = os.path.join(extracted_dir, csv_file_name1)


# Download zip file 1 and Extract
response = requests.get(url1)
with open(local_zip_path1, 'wb') as f:
    f.write(response.content)

with zipfile.ZipFile(local_zip_path1, 'r') as zip_ref:
    # Extract all files
    zip_ref.extractall(extracted_dir)


# create Duckdb Database
conn = duckdb.connect("employment.db")

create_table_query1 = f"""
CREATE OR REPLACE TABLE  business_employment AS
SELECT * FROM read_csv_auto('{csv_file_path1}');
"""


# Create Tables
conn.execute(create_table_query1)


conn.sql ("SHOW ALL TABLES").show()
cur_time = time.time()

conn.sql("""
-- Step 1: Filter records to include only those with 'Filled jobs' in Series_title_1
-- and 'Territorial authority' in the 'Group' field, and where 'data_value' is not null.
WITH FilteredRecords AS (
    SELECT Period,"Group" as group_name, Series_title_1, data_value
    FROM business_employment
    WHERE Series_title_1 LIKE 'Filled jobs'
      AND "Group" LIKE 'Territorial authority%'
      AND data_value IS NOT NULL
)

-- Step 2: Aggregate the filtered records by 'Period', calculating the sum and average of 'data_value'.
SELECT
    Period, group_name, Series_title_1,
    SUM(data_value) AS total_data_value,
    AVG(data_value) AS avg_data_value
FROM FilteredRecords
GROUP BY Period, group_name, Series_title_1

-- Step 3: Order the results by the average 'data_value' in descending order.
ORDER BY avg_data_value DESC;

""").show()

print(f"time2: {time.time() - cur_time}")

conn.close()
# Out:
# ┌────────────┬─────────┬─────────────────────┬──────────────────────┬──────────────────────────────────────┬───────────┐
# │  database  │ schema  │        name         │     column_names     │             column_types             │ temporary │
# │  varchar   │ varchar │       varchar       │      varchar[]       │              varchar[]               │  boolean  │
# ├────────────┼─────────┼─────────────────────┼──────────────────────┼──────────────────────────────────────┼───────────┤
# │ employment │ main    │ business_employment │ [Series_reference,…  │ [VARCHAR, DOUBLE, DOUBLE, VARCHAR,…  │ false     │
# └────────────┴─────────┴─────────────────────┴──────────────────────┴──────────────────────────────────────┴───────────┘
#
# ┌─────────┬──────────────────────────────────────────────┬────────────────┬──────────────────┬────────────────────┐
# │ Period  │                  group_name                  │ Series_title_1 │ total_data_value │   avg_data_value   │
# │ double  │                   varchar                    │    varchar     │      double      │       double       │
# ├─────────┼──────────────────────────────────────────────┼────────────────┼──────────────────┼────────────────────┤
# │ 2023.12 │ Territorial authority by employment variable │ Filled jobs    │        2321302.0 │ 34646.298507462685 │
# │ 2024.03 │ Territorial authority by employment variable │ Filled jobs    │        2303656.0 │  34382.92537313433 │
# │ 2023.06 │ Territorial authority by employment variable │ Filled jobs    │        2289997.0 │  34179.05970149254 │
# │ 2023.09 │ Territorial authority by employment variable │ Filled jobs    │        2276387.0 │  33975.92537313433 │
# │ 2023.03 │ Territorial authority by employment variable │ Filled jobs    │        2257853.0 │ 33699.298507462685 │
# │ 2022.12 │ Territorial authority by employment variable │ Filled jobs    │        2256451.0 │  33678.37313432836 │
# │ 2021.12 │ Territorial authority by employment variable │ Filled jobs    │        2215808.0 │  33071.76119402985 │
# │ 2022.09 │ Territorial authority by employment variable │ Filled jobs    │        2209338.0 │  32975.19402985075 │
# │ 2022.06 │ Territorial authority by employment variable │ Filled jobs    │        2208941.0 │  32969.26865671642 │
# │ 2022.03 │ Territorial authority by employment variable │ Filled jobs    │        2196169.0 │  32778.64179104478 │
# │    ·    │                      ·                       │      ·         │            ·     │          ·         │
# │    ·    │                      ·                       │      ·         │            ·     │          ·         │
# │    ·    │                      ·                       │      ·         │            ·     │          ·         │
# │ 2013.06 │ Territorial authority by employment variable │ Filled jobs    │        1788352.0 │  26691.82089552239 │
# │ 2013.09 │ Territorial authority by employment variable │ Filled jobs    │        1773041.0 │ 26463.298507462685 │
# │ 2012.12 │ Territorial authority by employment variable │ Filled jobs    │        1769156.0 │  26405.31343283582 │
# │ 2012.06 │ Territorial authority by employment variable │ Filled jobs    │        1757322.0 │  26228.68656716418 │
# │ 2013.03 │ Territorial authority by employment variable │ Filled jobs    │        1757289.0 │ 26228.194029850747 │
# │ 2011.12 │ Territorial authority by employment variable │ Filled jobs    │        1755028.0 │  26194.44776119403 │
# │ 2012.09 │ Territorial authority by employment variable │ Filled jobs    │        1737707.0 │ 25935.925373134327 │
# │ 2012.03 │ Territorial authority by employment variable │ Filled jobs    │        1728913.0 │ 25804.671641791047 │
# │ 2011.06 │ Territorial authority by employment variable │ Filled jobs    │        1726876.0 │ 25774.268656716416 │
# │ 2011.09 │ Territorial authority by employment variable │ Filled jobs    │        1725118.0 │  25748.02985074627 │
# ├─────────┴──────────────────────────────────────────────┴────────────────┴──────────────────┴────────────────────┤
# │ 52 rows (20 shown)                                                                                    5 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# time2: 0.06423807144165039
